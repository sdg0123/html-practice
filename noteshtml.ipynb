# %% [markdown]
# html 1 - 1993 -- simple feature
# html 2 - 1995 --  expanded html
# html 3 - 1997 -- support for css
# html 4 - 1999 -- minor bug update
# html 4 01 - 2012-- <frames> tag improved
# html 5 -- 2014 -- media element were added

# %% [markdown]
# <html>
# <head>
# <body>
# <Title>
# <meta>
# <link>
# <style>

# %% [markdown]
# html removed below tags from html 5
# <frame> it is used to create frames
# <applet> it is used to add small javacode -- <object>or <embed>
# <center> it is used to centre the text or element
# <font> it is used to specify the font size
